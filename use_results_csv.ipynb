# %%
import pandas as pd

# %%
result_table = pd.read_csv('output/output.csv', index_col=0).sort_index()
result_table
# Out:
#              lat    lon     result1       result2
# index
# 0      10.837696  10.00  286.125549  53097.082581
# 1      10.837696  11.25  286.560181  53165.210571
# 2      10.837696  12.50  286.388641  53156.736298
# 3      10.837696  13.75  286.896454  53236.369110
# 4      10.837696  15.00  288.430725  53409.049866
# ...          ...    ...         ...           ...
# 85     19.319372  15.00  279.046722  52362.896332
# 86     19.319372  16.25  281.227631  52601.837006
# 87     19.319372  17.50  280.167023  52393.407257
# 88     19.319372  18.75  279.102661  52346.880005
# 89     19.319372  20.00  277.807434  52098.694153
#
# [90 rows x 4 columns]

# %% [markdown]
# ### Transform to xarray

# %%
import xarray as xr
import numpy as np

# %%
lat = np.unique(result_table.lat.values)
lon = np.unique(result_table.lon.values)

result1 = xr.DataArray(
    result_table.result1.values.reshape((len(lat),len(lon))),
    dims=['lat','lon'],
    coords=dict(lat=lat, lon=lon)
)

# %%
# check if everything is ok
original_data = xr.open_dataset('/climca/data/CESM2_LE/TREFHTMN/mon_raw/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.cam.h0.TREFHTMN.201001-201412.nc')['TREFHTMN']
original_data = original_data.loc[:,10:20,10:20].load()

# %%
result1.values - original_data[0]
# Out:
# <xarray.DataArray 'TREFHTMN' (lat: 10, lon: 9)>
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.68434189e-14,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.68434189e-14,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -5.68434189e-14,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.68434189e-14, -5.68434189e-14,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
# ...
